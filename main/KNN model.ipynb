# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd

# %%
df = pd.read_csv("train_data.csv")
test = pd.read_csv("test_data.csv")

# %% [markdown]
# Analysing the data

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.000018  0.000043  0.000033  0.000008  0.000018  0.000168 -0.037158
# 1 -0.000001 -0.000017 -0.000091 -0.000002 -0.000005  0.000030  0.003444
# 2 -0.000008  0.000022  0.000273 -0.000013  0.000045  0.000235 -0.031176
# 3 -0.000003 -0.000024 -0.000068 -0.000004 -0.000014  0.000208  0.011901
# 4  0.000001 -0.000046 -0.000155 -0.000005 -0.000003 -0.000062  0.002543
#
#           7         8         9  ...       39       40       41      42  \
# 0 -0.037202 -0.037235 -0.010982  ... -0.67649  0.96055   8.6993 -1.5021
# 1  0.003460  0.003551 -0.044235  ... -0.76999  6.98720   3.7207 -1.5000
# 2 -0.031198 -0.031471 -0.005473  ... -0.50284  2.72700   3.6334 -1.5067
# 3  0.011925  0.011993 -0.010714  ... -0.82455  5.36100  11.3180 -1.4998
# 4  0.002589  0.002744 -0.037649  ... -0.70297  1.80770   2.5276 -1.5059
#
#        43      44      45      46      47  class
# 0 -1.5021 -1.5017 -1.4932 -1.4933 -1.4934     10
# 1 -1.5000 -1.5001 -1.4996 -1.4996 -1.4996      9
# 2 -1.5067 -1.5068 -1.4977 -1.4978 -1.4978     10
# 3 -1.4998 -1.4998 -1.5001 -1.5002 -1.5000      9
# 4 -1.5058 -1.5055 -1.4992 -1.4992 -1.4992      9
#
# [5 rows x 49 columns]

# %%
test.head()
# Out:
#           0             1         2             3         4         5  \
# 0  0.000015  2.261000e-04  0.000143  1.301300e-05  0.000024  0.000166
# 1  0.000001  1.096700e-06  0.000007  3.286500e-06 -0.000004 -0.000024
# 2 -0.000003 -5.314800e-07  0.000009  1.214500e-06  0.000002  0.000001
# 3 -0.000016 -8.144400e-06  0.000359 -1.369800e-05 -0.000067 -0.000209
# 4  0.000001 -1.767300e-06 -0.000006 -6.491500e-07  0.000001 -0.000005
#
#           6         7         8         9  ...      38       39        40  \
# 0  0.017538  0.017312  0.017169 -0.024930  ...  5.3318 -0.51178   1.82140
# 1  0.016444  0.016443  0.016436  0.018125  ...  5.7592 -0.60895   5.11230
# 2  0.023619  0.023619  0.023610  0.010662  ...  7.7757 -0.43207   9.65110
# 3 -0.105600 -0.105600 -0.105950 -0.135700  ...  6.7772 -0.63783  -0.10986
# 4  0.067877  0.067878  0.067885  0.111340  ...  5.6022 -0.50386  16.48400
#
#        41      42      43      44      45      46      47
# 0  4.4189 -1.5069 -1.5071 -1.5071 -1.4958 -1.4957 -1.4956
# 1  3.3354 -1.4990 -1.4990 -1.4989 -1.4967 -1.4967 -1.4966
# 2  7.3805 -1.4988 -1.4988 -1.4988 -1.4999 -1.4999 -1.4999
# 3  3.8331 -1.4978 -1.4979 -1.4975 -1.5033 -1.5034 -1.5032
# 4  5.8570 -1.4980 -1.4980 -1.4980 -1.4972 -1.4971 -1.4971
#
# [5 rows x 48 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46807 entries, 0 to 46806
# Data columns (total 49 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       46807 non-null  float64
#  1   1       46807 non-null  float64
#  2   2       46807 non-null  float64
#  3   3       46807 non-null  float64
#  4   4       46807 non-null  float64
#  5   5       46807 non-null  float64
#  6   6       46807 non-null  float64
#  7   7       46807 non-null  float64
#  8   8       46807 non-null  float64
#  9   9       46807 non-null  float64
#  10  10      46807 non-null  float64
#  11  11      46807 non-null  float64
#  12  12      46807 non-null  float64
#  13  13      46807 non-null  float64
#  14  14      46807 non-null  float64
#  15  15      46807 non-null  float64
#  16  16      46807 non-null  float64
#  17  17      46807 non-null  float64
#  18  18      46807 non-null  float64
#  19  19      46807 non-null  float64
#  20  20      46807 non-null  float64
#  21  21      46807 non-null  float64
#  22  22      46807 non-null  float64
#  23  23      46807 non-null  float64
#  24  24      46807 non-null  float64
#  25  25      46807 non-null  float64
#  26  26      46807 non-null  float64
#  27  27      46807 non-null  float64
#  28  28      46807 non-null  float64
#  29  29      46807 non-null  float64
#  30  30      46807 non-null  float64
#  31  31      46807 non-null  float64
#  32  32      46807 non-null  float64
#  33  33      46807 non-null  float64
#  34  34      46807 non-null  float64
#  35  35      46807 non-null  float64
#  36  36      46807 non-null  float64
#  37  37      46807 non-null  float64
#  38  38      46807 non-null  float64
#  39  39      46807 non-null  float64
#  40  40      46807 non-null  float64
#  41  41      46807 non-null  float64
#  42  42      46807 non-null  float64
#  43  43      46807 non-null  float64
#  44  44      46807 non-null  float64
#  45  45      46807 non-null  float64
#  46  46      46807 non-null  float64
#  47  47      46807 non-null  float64
#  48  class   46807 non-null  int64
# dtypes: float64(48), int64(1)
# memory usage: 17.5 MB

# %% [markdown]
# getting some more insights of the trainig data using describe method

# %%
df.nunique()
# Out:
# 0        41466
# 1        43047
# 2        42840
# 3        42086
# 4        42934
# 5        42812
# 6        36770
# 7        36769
# 8        36762
# 9        37153
# 10       37225
# 11       37266
# 12       15519
# 13       25948
# 14       36287
# 15       16395
# 16       25887
# 17       36135
# 18       11964
# 19       11927
# 20       11857
# 21       11890
# 22       11892
# 23       11828
# 24       40360
# 25       42382
# 26       42244
# 27       41000
# 28       42394
# 29       42261
# 30       41177
# 31       41139
# 32       41141
# 33       41672
# 34       41847
# 35       41786
# 36       26054
# 37       38716
# 38       36029
# 39       26427
# 40       38994
# 41       35956
# 42         259
# 43         262
# 44         258
# 45         234
# 46         237
# 47         238
# class       11
# dtype: int64

# %%
df.describe()
# Out:
#                   0             1             2             3             4  \
# count  46807.000000  4.680700e+04  4.680700e+04  46807.000000  4.680700e+04
# mean      -0.000003  1.415116e-06  9.925226e-07     -0.000001  1.207948e-06
# std        0.000080  5.869695e-05  2.372014e-04      0.000070  6.013258e-05
# min       -0.013721 -5.414400e-03 -1.358000e-02     -0.012787 -8.355900e-03
# 25%       -0.000007 -1.442100e-05 -7.270050e-05     -0.000005 -1.499750e-05
# 50%       -0.000003  8.966400e-07  4.999900e-07     -0.000001  6.887400e-07
# 75%        0.000002  1.884650e-05  7.459750e-05      0.000004  1.886350e-05
# max        0.005784  4.525300e-03  3.330400e-03      0.001453  8.245100e-04
#
#                   5             6             7             8             9  \
# count  4.680700e+04  46807.000000  46807.000000  46807.000000  46807.000000
# mean  -7.075103e-07      0.001882      0.001881      0.001880     -0.011906
# std    2.278823e-04      0.036524      0.036521      0.036526      0.066422
# min   -9.741300e-03     -0.139890     -0.135940     -0.130860     -0.218640
# 25%   -7.455400e-05     -0.019870     -0.019911     -0.019887     -0.032113
# 50%   -3.926500e-07      0.013179      0.013185      0.013200     -0.015464
# 75%    7.077650e-05      0.024758      0.024763      0.024766      0.020449
# max    2.753600e-03      0.069125      0.069130      0.069131      0.352580
#
#        ...            39            40            41            42  \
# count  ...  46807.000000  46807.000000  46807.000000  46807.000000
# mean   ...     -0.337555      7.300926      8.271516     -1.500881
# std    ...     27.964812     12.600663      6.583845      0.003661
# min    ...     -0.902350     -0.596830      0.320660     -1.525500
# 25%    ...     -0.715590      1.452650      4.437100     -1.503300
# 50%    ...     -0.661920      3.310100      6.463100     -1.500300
# 75%    ...     -0.573910      8.289450      9.861250     -1.498200
# max    ...   3670.800000    889.930000    153.150000     -1.457600
#
#                  43            44            45            46            47  \
# count  46807.000000  46807.000000  46807.000000  46807.000000  46807.000000
# mean      -1.500905     -1.500799     -1.497778     -1.497800     -1.497692
# std        0.003671      0.003635      0.003176      0.003176      0.003187
# min       -1.526200     -1.523700     -1.521400     -1.523200     -1.521300
# 25%       -1.503400     -1.503200     -1.499600     -1.499600     -1.499600
# 50%       -1.500300     -1.500300     -1.498100     -1.498100     -1.498000
# 75%       -1.498200     -1.498200     -1.496200     -1.496300     -1.496200
# max       -1.456100     -1.455500     -1.337200     -1.337200     -1.337100
#
#               class
# count  46807.000000
# mean       6.014357
# std        3.156842
# min        1.000000
# 25%        3.000000
# 50%        6.000000
# 75%        9.000000
# max       11.000000
#
# [8 rows x 49 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop("class", axis=1),df['class'],test_size=0.20)

# %%
X_train
# Out:
#                   0         1         2         3         4         5  \
# 38861  1.939500e-06  0.000002  0.000017  0.000002  0.000006 -0.000005
# 15473 -1.457100e-05  0.000017 -0.000415 -0.000012 -0.000062 -0.000307
# 14827  1.688100e-05  0.000040  0.000726  0.000010  0.000031 -0.000121
# 4809  -4.632900e-06  0.000017 -0.000067 -0.000006  0.000010  0.000114
# 25333  6.520400e-06 -0.000068 -0.000206  0.000007  0.000008  0.000156
# ...             ...       ...       ...       ...       ...       ...
# 33560  9.359000e-06  0.000010  0.000243 -0.000009  0.000068 -0.000167
# 28951  1.980500e-05  0.000008  0.000108 -0.000002  0.000059  0.000022
# 39221  5.841000e-07  0.000047  0.000066 -0.000002  0.000028  0.000097
# 21873 -1.305600e-05 -0.000029 -0.000018 -0.000016 -0.000019  0.000195
# 33272 -5.064800e-06 -0.000084 -0.000032 -0.000015 -0.000066 -0.000130
#
#               6         7         8         9  ...       38       39  \
# 38861  0.052385  0.052383  0.052366  0.113090  ...   6.2146 -0.61554
# 15473 -0.048301 -0.048318 -0.047904 -0.176780  ...   1.0941 -0.56368
# 14827  0.026464  0.026425  0.025698  0.111500  ...   8.5020 -0.65617
# 4809  -0.022334 -0.022351 -0.022284 -0.031699  ...  10.1890 -0.64888
# 25333  0.010066  0.010134  0.010340  0.013588  ...   3.1555 -0.62945
# ...         ...       ...       ...       ...  ...      ...      ...
# 33560  0.006935  0.006925  0.006682  0.000930  ...   5.8836 -0.72191
# 28951 -0.021353 -0.021361 -0.021470 -0.030526  ...   7.2428 -0.58290
# 39221  0.014689  0.014642  0.014576 -0.039578  ...  16.2850 -0.84517
# 21873  0.014837  0.014866  0.014884 -0.027805  ...   5.4282 -0.68925
# 33272  0.028724  0.028808  0.028840  0.022805  ...   4.1712 -0.55651
#
#              40       41      42      43      44      45      46      47
# 38861  22.20100   6.9783 -1.4984 -1.4984 -1.4984 -1.4950 -1.4950 -1.4949
# 15473   3.06830   5.8542 -1.4952 -1.4952 -1.4948 -1.5014 -1.5014 -1.5014
# 14827   2.01270   3.9698 -1.5042 -1.5043 -1.5045 -1.4924 -1.4924 -1.4920
# 4809    0.33428  12.3530 -1.4990 -1.4990 -1.4990 -1.4988 -1.4988 -1.4990
# 25333   3.90250   3.8628 -1.4998 -1.4999 -1.4997 -1.5013 -1.5014 -1.5011
# ...         ...      ...     ...     ...     ...     ...     ...     ...
# 33560   0.88418   2.2070 -1.5053 -1.5053 -1.5058 -1.4953 -1.4954 -1.4951
# 28951   2.75890   7.2211 -1.5064 -1.5064 -1.5066 -1.4977 -1.4977 -1.4977
# 39221  26.82000  23.4120 -1.5005 -1.5005 -1.5005 -1.4993 -1.4993 -1.4993
# 21873   2.44200   2.9357 -1.5075 -1.5074 -1.5076 -1.4979 -1.4978 -1.4974
# 33272   1.93070   4.8106 -1.5001 -1.5003 -1.5002 -1.4979 -1.4979 -1.4978
#
# [37445 rows x 48 columns]

# %% [markdown]
# ### Preprocessing the data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
scaler.fit(test)
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(X_train)
scaled_valid = scaler.transform(X_test)
scaled_test = scaler.transform(test)

# %%
scaled_features
# Out:
# array([[ 0.58174778,  0.01608573,  0.05929286, ...,  0.88252603,
#          0.88963959,  0.88402279],
#        [-1.32889051,  0.37918787, -1.83560441, ..., -1.17411362,
#         -1.16683129, -1.19631882],
#        [ 2.31081728,  0.94248387,  3.17835729, ...,  1.71803588,
#          1.72508089,  1.8121752 ],
#        ...,
#        [ 0.42489734,  1.12416049,  0.27489268, ..., -0.49927873,
#         -0.49205178, -0.52420845],
#        [-1.15357074, -0.75141676, -0.09240405, ..., -0.04938881,
#         -0.01006642,  0.0838914 ],
#        [-0.22880816, -2.11052036, -0.15404356, ..., -0.04938881,
#         -0.04219878, -0.04412962]])

# %%
df_train = pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_val = pd.DataFrame(scaled_valid,columns=df.columns[:-1])
df_test = pd.DataFrame(scaled_test,columns=df.columns[:-1])
df_train.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.581748  0.016086  0.059293  0.343123  0.113567 -0.027486  1.389027
# 1 -1.328891  0.379188 -1.835604 -1.238591 -1.618106 -1.406444 -1.389121
# 2  2.310817  0.942484  3.178357  1.196910  0.730313 -0.556365  0.673810
# 3 -0.178828  0.392457 -0.308184 -0.617116  0.207029  0.511148 -0.672634
# 4  1.111862 -1.720359 -0.919516  0.938195  0.159097  0.703591  0.221353
#
#           7         8         9  ...        38        39        40        41  \
# 0  1.389076  1.388513  1.872745  ... -0.316444  0.018703  1.261733 -0.200881
# 1 -1.389610 -1.377923 -2.471704  ... -1.060977  0.060836 -0.354542 -0.373982
# 2  0.672806  0.652746  1.848915  ...  0.016149 -0.014306 -0.443716 -0.664163
# 3 -0.673092 -0.671071 -0.297292  ...  0.261443 -0.008384 -0.585504  0.626775
# 4  0.223281  0.229021  0.381451  ... -0.761244  0.007402 -0.284071 -0.680640
#
#          42        43        44        45        46        47
# 0  0.689535  0.694488  0.670539  0.882526  0.889640  0.884023
# 1  1.567770  1.570549  1.665591 -1.174114 -1.166831 -1.196319
# 2 -0.902264 -0.920751 -1.015521  1.718036  1.725081  1.812175
# 3  0.524866  0.530226  0.504697 -0.338604 -0.331390 -0.428193
# 4  0.305308  0.283834  0.311215 -1.141979 -1.166831 -1.100303
#
# [5 rows x 48 columns]

# %% [markdown]
# ### using gridsearch to found the optimum parameters which is dominating n_neighbours in KNN model

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# %%
parameters = {'n_neighbors':[5,10, 20, 50, 80, 100, 500]}

knn = KNeighborsClassifier()
gs = GridSearchCV(knn, parameters, n_jobs=-1)
gs.fit(df_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': [5, 10, 20, 50, 80, 100, 500]})

# %%
gs.best_params_
# Out:
# {'n_neighbors': 10}

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(df_train,y_train)
pred_knn = knn.predict(df_val)

# %%
from sklearn.metrics import accuracy_score, mean_squared_error

# %%
mean_squared_error(y_test,pred_knn)
# Out:
# np.float64(4.659474471266823)

# %%
print(accuracy_score(y_test,pred_knn))
# Out:
# 0.8135013885921811
